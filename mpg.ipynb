# %%
import seaborn as sns

# %%
mpg = sns.load_dataset("mpg")

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.histplot(data = mpg, x= "mpg")

# %%
sns.scatterplot(data = mpg,x = "mpg",y = "horsepower")

# %%
sns.boxplot(data = mpg,x="origin",y = "acceleration")

# %% [markdown]
# usa has the largest variety of cars ranging from the slowest to second fatest europe has the faster average however it also has the fastest acceleeration and japan has the highest mean accelerations

# %%
sns.kdeplot(data=mpg,x = "acceleration")

# %% [markdown]
# acceleration from all the origins have an average of 15

# %%
sns.kdeplot(data=mpg,x = "acceleration",hue = "origin")

# %% [markdown]
# due to usa having the most cars their average density is 15 and erope has the highest acceleration cars

# %%
sns.histplot(data = mpg,x = "origin")

# %% [markdown]
# most the cars originated from usa dramatically japan just above europe

# %%
sns.histplot(data=mpg,x = "horsepower",kde = True)

# %% [markdown]
# the highest amount of cars were 100 horsepower

# %%
sns.histplot(data = mpg,x ="model_year")

# %% [markdown]
# the most cars were made in 78

# %%
sns.boxplot(data = mpg,x = "model_year",y = "acceleration")

# %% [markdown]
# from 1970 we have increased acceleration however its slow mean growth

# %%
sns.scatterplot(data = mpg,x = "model_year",y = "acceleration")

# %% [markdown]
# our acceleration mean has not increased dramaatically

# %%
sns.scatterplot(data = mpg,x = "model_year",y = "horsepower")

# %% [markdown]
# horsepower is decreased over time to increase mpg

# %%
sns.boxplot(data = mpg,x = "model_year",y = "horsepower")

# %% [markdown]
# horse power is decreased troughout the 12 years howelver 1982 has a higher mean horsepower

# %%
sns.boxplot(data = mpg, x = "model_year",y = "mpg")

# %% [markdown]
# mpg is increased over the 12 years gradually
